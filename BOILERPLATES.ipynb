# %% [markdown]
# ### Boilerplates

# %% [raw]
# from PIL import Image
# import os
#
# path = r'C:\Users\david.han\Desktop\COPY_images_files'
# for file in os.listdir(path):
#     if file.endswith(".jpg"):
#         img = Image.open(file)
#         file_name, file_ext = os.path.splitext(file)
#         img.save('/png/{}.png'.format(file_name))

# %% [raw]
# os.name

# %% [raw]
# os.error

# %% [raw]
# os.environ

# %% [raw]
# os.getcwd()

# %% [raw]
# os.listdir()

# %% [markdown]
# ![23911os.walk.png](attachment:a48416a4-6881-4244-8e11-31eb5edc3652.png)

# %% [markdown]
# ![11854os.path.basename.png](attachment:f1917db9-096d-48fd-b7cd-ab18c912e8da.png)

# %% [markdown]
# - os.path.split() :
# This method splits the pathname into a pair of head and tail. Here, the tail is the last pathname component and the head is everything that comes before it. The method returns a **tuple of the head and tail** of the specified path.
#
# ![54875os.path.split.png](attachment:88c74d7a-a170-4f22-84ca-2fd9561c03e6.png)

# %% [markdown]
#  - os.path.normpath() :
# This method normalises the specified path name by collapsing redundant separators and up-level references.
# ![30153os.path.normpath.png](attachment:751a54ca-9df5-4ee5-9e10-3e578ba2550c.png)

# %% [markdown]
# - os.path.commonprefix() :
# This method returns the longest path prefix which is a prefix for all the paths in the specified list.
#
# ![53342os.apth.commonprefix.png](attachment:c354bbf0-b149-4127-9ad9-97b38415389c.png)
